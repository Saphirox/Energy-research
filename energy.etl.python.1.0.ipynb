# %% [markdown]
# # Extract-Transform-Load (ETL)

# %% [markdown]
# This notebook covers ETLs. ETL covers transforming data to more processing view.

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Install engine for parquet.

# %%
# !conda install -c conda-forge pyarrow
# !conda install numpy=1.14
#pip install numpy --version a1.14.0
# Out:
# ...
#     100% |████████████████████████████████| 25.7MB 35kB/s  eta 0:00:01
# Requirement not upgraded as not directly required: numpy>=1.9.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas==0.21.0)
# Requirement not upgraded as not directly required: python-dateutil>=2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas==0.21.0)
# Requirement not upgraded as not directly required: pytz>=2011k in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas==0.21.0)
# Requirement not upgraded as not directly required: six>=1.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from python-dateutil>=2->pandas==0.21.0)
# ...
#   Found existing installation: pandas 0.19.0
#     Uninstalling pandas-0.19.0:
#       Successfully uninstalled pandas-0.19.0
# ...

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_data_1.to_parquet('pp_df.npy')

# %% [markdown]
# Upload file to the application bucket

# %%
cos.upload_file(Filename='pp_df.npy', Bucket=credentials['BUCKET'],Key='pp_df.npy')
print('Success')
# Out:
# Success
